# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -l '/content/drive/My Drive/Colab Notebooks/datasets/hap_emb_hurt_ang_neu.zip'
# Out:
# -rw------- 1 root root 1386821562 Nov  4 06:21 '/content/drive/My Drive/Colab Notebooks/datasets/hap_emb_hurt_ang_neu.zip'

# %%
# !unzip /content/drive/MyDrive/Colab\ Notebooks/datasets/hap_emb_hurt_ang_neu.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: valid/ang/054b1e76bacf338595bd6718f1f208ff2d2bbc5a4803d3213dfd580976dacfcf_│▓_30_║╨│ы_╣о╚н└ч ╣╫ └п└√┴Ў_20201206183202-009-001.jpg
#   inflating: valid/ang/054b1e76bacf338595bd6718f1f208ff2d2bbc5a4803d3213dfd580976dacfcf_│▓_30_║╨│ы_╣о╚н└ч ╣╫ └п└√┴Ў_20201206183202-009-002.jpg
#   inflating: valid/ang/054b1e76bacf338595bd6718f1f208ff2d2bbc5a4803d3213dfd580976dacfcf_│▓_30_║╨│ы_╗є╛ў╜├╝│_┴б╞ў_╜├└х_20201206183059-003-010.jpg
#   inflating: valid/ang/054b1e76bacf338595bd6718f1f208ff2d2bbc5a4803d3213dfd580976dacfcf_│▓_30_║╨│ы_╗є╛ў╜├╝│_┴б╞ў_╜├└х_20201206183059-003-024.jpg
#   inflating: valid/ang/054b1e76bacf338595bd6718f1f208ff2d2bbc5a4803d3213dfd580976dacfcf_│▓_30_║╨│ы_╗є╛ў╜├╝│_┴б╞ў_╜├└х_20201206183059-003-031.jpg
#   inflating: valid/ang/054b1e76bacf338595bd6718f1f208ff2d2bbc5a4803d3213dfd580976dacfcf_│▓_30_║╨│ы_╗є╛ў╜├╝│_┴б╞ў_╜├└х_20201206183059-003-034.jpg
# ...

# %%
# !ls -l
# Out:
# total 16
# drwx------ 5 root root 4096 Nov  4 06:29 drive
# drwxr-xr-x 1 root root 4096 Nov  1 13:35 sample_data
# drwxr-xr-x 7 root root 4096 Nov  4 06:29 train
# drwxr-xr-x 7 root root 4096 Nov  4 06:30 valid

# %%
train_dir = 'train'
valid_dir = 'valid'

# %% [markdown]
# # build model

# %%
from tensorflow.keras import layers
from tensorflow.keras import models

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (150, 200, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation = 'relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation = 'relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation = 'relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation = 'relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation = 'relu'))
model.add(layers.Dense(5, activation = 'softmax'))

model.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_29 (Conv2D)           (None, 148, 198, 32)      896
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 74, 99, 32)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 72, 97, 64)        18496
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 36, 48, 64)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 34, 46, 128)       73856
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 17, 23, 128)       0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 15, 21, 128)       147584
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)

valid_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150,200),
    batch_size=20,
    class_mode = 'categorical')

valid_generator = valid_datagen.flow_from_directory(
    valid_dir,
    target_size = (150, 200),
    batch_size = 20,
    class_mode = 'categorical')
# Out:
# Found 10000 images belonging to 5 classes.
# Found 5000 images belonging to 5 classes.

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=200,
    epochs=20,
    validation_data=valid_generator,
    validation_steps=50)
# Out:
# Epoch 1/20
# 200/200 [==============================] - 125s 627ms/step - loss: 1.6098 - accuracy: 0.1925 - val_loss: 1.6096 - val_accuracy: 0.2000
# Epoch 2/20
# 200/200 [==============================] - 126s 632ms/step - loss: 1.6094 - accuracy: 0.2050 - val_loss: 1.6097 - val_accuracy: 0.2000
# Epoch 3/20
# 200/200 [==============================] - 126s 633ms/step - loss: 1.6099 - accuracy: 0.1922 - val_loss: 1.6095 - val_accuracy: 0.2000
# Epoch 4/20
# 200/200 [==============================] - 126s 633ms/step - loss: 1.6097 - accuracy: 0.1898 - val_loss: 1.6095 - val_accuracy: 0.2000
# Epoch 5/20
# 200/200 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.2037
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-8490a04547d1> in <module>()
#       4     epochs=20,
#       5     validation_data=valid_generator,
# ...
